# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df = pd.read_csv("/kaggle/input/ann-car-sales-price-prediction/car_purchasing.csv",encoding='ISO-8859-1')

# %%
df.head()
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# 2  638467.1773          42925.70921
# 3  548599.0524          67422.36313
# 4  560304.0671          55915.46248

# %%
df.drop(columns = ["customer name","customer e-mail","country","gender"],axis = 1,inplace = True)

# %%
X = df.drop("car purchase amount",axis = 1)
Y = df["car purchase amount"]

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(X)
Y = scaler.fit_transform(Y.values.reshape(-1,1))

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
model = Sequential()

model.add(Dense(10,activation = 'relu',input_dim=4))
model.add(Dense(10,activation = 'relu'))
model.add(Dense(1,activation = 'linear'))

model.compile(optimizer = 'adam',loss = "mean_squared_error",metrics=["mean_absolute_error"])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                50
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 171
# Trainable params: 171
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train,y_train,epochs = 50 , validation_split = 0.2)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 5s 27ms/step - loss: 0.1275 - mean_absolute_error: 0.3338 - val_loss: 0.0856 - val_mean_absolute_error: 0.2719
# Epoch 2/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0789 - mean_absolute_error: 0.2538 - val_loss: 0.0488 - val_mean_absolute_error: 0.1975
# Epoch 3/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0455 - mean_absolute_error: 0.1841 - val_loss: 0.0256 - val_mean_absolute_error: 0.1347
# Epoch 4/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0249 - mean_absolute_error: 0.1310 - val_loss: 0.0140 - val_mean_absolute_error: 0.0934
# Epoch 5/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0147 - mean_absolute_error: 0.0965 - val_loss: 0.0100 - val_mean_absolute_error: 0.0771
# Epoch 6/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0113 - mean_absolute_error: 0.0845 - val_loss: 0.0094 - val_mean_absolute_error: 0.0740
# Epoch 7/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0101 - mean_absolute_error: 0.0793 - val_loss: 0.0091 - val_mean_absolute_error: 0.0734
# Epoch 8/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0097 - mean_absolute_error: 0.0780 - val_loss: 0.0086 - val_mean_absolute_error: 0.0711
# Epoch 9/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0092 - mean_absolute_error: 0.0758 - val_loss: 0.0078 - val_mean_absolute_error: 0.0676
# Epoch 10/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0086 - mean_absolute_error: 0.0733 - val_loss: 0.0070 - val_mean_absolute_error: 0.0640
# Epoch 11/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0081 - mean_absolute_error: 0.0711 - val_loss: 0.0064 - val_mean_absolute_error: 0.0611
# Epoch 12/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0077 - mean_absolute_error: 0.0691 - val_loss: 0.0060 - val_mean_absolute_error: 0.0584
# Epoch 13/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0072 - mean_absolute_error: 0.0668 - val_loss: 0.0054 - val_mean_absolute_error: 0.0550
# Epoch 14/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0067 - mean_absolute_error: 0.0648 - val_loss: 0.0049 - val_mean_absolute_error: 0.0518
# Epoch 15/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0062 - mean_absolute_error: 0.0622 - val_loss: 0.0047 - val_mean_absolute_error: 0.0509
# Epoch 16/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0057 - mean_absolute_error: 0.0600 - val_loss: 0.0046 - val_mean_absolute_error: 0.0505
# Epoch 17/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0054 - mean_absolute_error: 0.0585 - val_loss: 0.0045 - val_mean_absolute_error: 0.0502
# Epoch 18/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0052 - mean_absolute_error: 0.0573 - val_loss: 0.0043 - val_mean_absolute_error: 0.0495
# Epoch 19/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0050 - mean_absolute_error: 0.0561 - val_loss: 0.0041 - val_mean_absolute_error: 0.0484
# Epoch 20/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0047 - mean_absolute_error: 0.0548 - val_loss: 0.0039 - val_mean_absolute_error: 0.0472
# Epoch 21/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0045 - mean_absolute_error: 0.0535 - val_loss: 0.0038 - val_mean_absolute_error: 0.0462
# Epoch 22/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0043 - mean_absolute_error: 0.0521 - val_loss: 0.0035 - val_mean_absolute_error: 0.0450
# Epoch 23/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0041 - mean_absolute_error: 0.0507 - val_loss: 0.0034 - val_mean_absolute_error: 0.0439
# Epoch 24/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0039 - mean_absolute_error: 0.0494 - val_loss: 0.0032 - val_mean_absolute_error: 0.0427
# Epoch 25/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0037 - mean_absolute_error: 0.0481 - val_loss: 0.0030 - val_mean_absolute_error: 0.0415
# Epoch 26/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0035 - mean_absolute_error: 0.0468 - val_loss: 0.0028 - val_mean_absolute_error: 0.0404
# Epoch 27/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0033 - mean_absolute_error: 0.0454 - val_loss: 0.0027 - val_mean_absolute_error: 0.0392
# Epoch 28/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0031 - mean_absolute_error: 0.0440 - val_loss: 0.0026 - val_mean_absolute_error: 0.0381
# Epoch 29/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0029 - mean_absolute_error: 0.0426 - val_loss: 0.0024 - val_mean_absolute_error: 0.0368
# Epoch 30/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0027 - mean_absolute_error: 0.0412 - val_loss: 0.0023 - val_mean_absolute_error: 0.0357
# Epoch 31/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0025 - mean_absolute_error: 0.0402 - val_loss: 0.0021 - val_mean_absolute_error: 0.0346
# Epoch 32/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0024 - mean_absolute_error: 0.0385 - val_loss: 0.0020 - val_mean_absolute_error: 0.0335
# Epoch 33/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0022 - mean_absolute_error: 0.0371 - val_loss: 0.0019 - val_mean_absolute_error: 0.0322
# Epoch 34/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0020 - mean_absolute_error: 0.0358 - val_loss: 0.0017 - val_mean_absolute_error: 0.0309
# Epoch 35/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0019 - mean_absolute_error: 0.0349 - val_loss: 0.0016 - val_mean_absolute_error: 0.0298
# Epoch 36/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0332 - val_loss: 0.0014 - val_mean_absolute_error: 0.0285
# Epoch 37/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0016 - mean_absolute_error: 0.0312 - val_loss: 0.0013 - val_mean_absolute_error: 0.0273
# Epoch 38/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0014 - mean_absolute_error: 0.0294 - val_loss: 0.0012 - val_mean_absolute_error: 0.0260
# Epoch 39/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0013 - mean_absolute_error: 0.0281 - val_loss: 0.0011 - val_mean_absolute_error: 0.0247
# Epoch 40/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0012 - mean_absolute_error: 0.0275 - val_loss: 9.7085e-04 - val_mean_absolute_error: 0.0234
# Epoch 41/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0011 - mean_absolute_error: 0.0256 - val_loss: 8.7460e-04 - val_mean_absolute_error: 0.0222
# Epoch 42/50
# 10/10 [==============================] - 0s 6ms/step - loss: 9.2579e-04 - mean_absolute_error: 0.0236 - val_loss: 7.8674e-04 - val_mean_absolute_error: 0.0211
# Epoch 43/50
# 10/10 [==============================] - 0s 6ms/step - loss: 8.2804e-04 - mean_absolute_error: 0.0223 - val_loss: 7.0649e-04 - val_mean_absolute_error: 0.0198
# Epoch 44/50
# 10/10 [==============================] - 0s 6ms/step - loss: 7.4188e-04 - mean_absolute_error: 0.0210 - val_loss: 6.2283e-04 - val_mean_absolute_error: 0.0186
# Epoch 45/50
# 10/10 [==============================] - 0s 6ms/step - loss: 6.6690e-04 - mean_absolute_error: 0.0198 - val_loss: 5.5231e-04 - val_mean_absolute_error: 0.0175
# Epoch 46/50
# 10/10 [==============================] - 0s 7ms/step - loss: 5.9475e-04 - mean_absolute_error: 0.0186 - val_loss: 4.8920e-04 - val_mean_absolute_error: 0.0165
# Epoch 47/50
# 10/10 [==============================] - 0s 6ms/step - loss: 5.2823e-04 - mean_absolute_error: 0.0174 - val_loss: 4.3333e-04 - val_mean_absolute_error: 0.0154
# Epoch 48/50
# 10/10 [==============================] - 0s 6ms/step - loss: 4.7189e-04 - mean_absolute_error: 0.0164 - val_loss: 3.8449e-04 - val_mean_absolute_error: 0.0145
# Epoch 49/50
# 10/10 [==============================] - 0s 6ms/step - loss: 4.1527e-04 - mean_absolute_error: 0.0153 - val_loss: 3.3552e-04 - val_mean_absolute_error: 0.0136
# Epoch 50/50
# 10/10 [==============================] - 0s 6ms/step - loss: 3.6708e-04 - mean_absolute_error: 0.0142 - val_loss: 2.9560e-04 - val_mean_absolute_error: 0.0128

# %%
# Define needed variables
tr_acc = history.history['mean_absolute_error']
tr_loss = history.history['loss']
val_acc = history.history['val_mean_absolute_error']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

# Plot training history
plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %%
y_pred = model.predict(x_test)
# Out:
# 4/4 [==============================] - 0s 2ms/step

# %%
from sklearn.metrics import r2_score

R2 = r2_score(y_test, y_pred)
print("R2 Score=",R2 )
# Out:
# R2 Score= 0.988407945511857
